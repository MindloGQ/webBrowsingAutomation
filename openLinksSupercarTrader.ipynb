# %%
import requests
from bs4 import BeautifulSoup

# %%
baseUrl = 'http://192.168.11.206:8080/Supercar-Trader/'
url = 'http://192.168.11.206:8080/Supercar-Trader/home.do'
print('sending GET method to {}'.format(url))
reqs = requests.get(url)
soup = BeautifulSoup(reqs.text, 'html.parser')

pages = []
nextPages = []
next2Pages = []

for link in soup.find_all('a'):
    page = link.get('href')
    if page != '' and page != None and not page.endswith('.jsp'):
        pages.append(page)

pages = list(set(pages))

for page in pages:
    nextUrl = baseUrl+page
    print('sending GET method to {}'.format(nextUrl))
    nextReqs = requests.get(nextUrl)
    nextSoup = BeautifulSoup(nextReqs.text, 'html.parser')

    for nextLink in nextSoup.find_all('a'):
        nextPage = nextLink.get('href')
        if nextPage != '' and nextPage != None and not nextPage.endswith('.jsp'):
            nextPages.append(nextPage)

nextPages = list(set(nextPages))

for nextPage in nextPages:                    
    next2Url = baseUrl+nextPage
    print('sending GET method to {}'.format(next2Url))
    next2Reqs = requests.get(next2Url)
    next2Soup = BeautifulSoup(next2Reqs.text, 'html.parser')
    
    for next2Link in next2Soup.find_all('a'):
        next2Page = next2Link.get('href')
        if next2Page != '' and next2Page != None and not next2Page.endswith('.jsp'):
            next2Pages.append(next2Page)

next2Pages = list(set(next2Pages))

for next2Page in next2Pages:                    
    next3Url = baseUrl+next2Page
    print('sending GET method to {}'.format(next3Url))
    next3Reqs = requests.get(next3Url)
# Out:
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/home.do
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/enquire.do
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/sell.do
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/about.do
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/supercars.do
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/insurance.do
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/home.do
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/search.do
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/cars.do?query=manu&mid=9
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/enquire.do
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/sell.do
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/about.do
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/cars.do?query=manu&mid=4
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/supercars.do
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/cars.do?query=manu&mid=2
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/cars.do?query=manu&mid=1
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/cars.do?query=manu&mid=8
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/cars.do?query=manu&mid=3
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/insurance.do
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/cars.do?query=manu&mid=7
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/cars.do?query=manu&mid=5
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/home.do
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/search.do
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/cars.do?query=manu&mid=6
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=10
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=26
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=35
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/enquire.do
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/cars.do?query=manu&mid=2
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=22
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/supercars.do
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=9
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=16
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/cars.do?query=manu&mid=7
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=28
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/home.do
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=11
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=37
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=12
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=30
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/cars.do?query=manu&mid=4
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=34
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=4
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/search.do
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=33
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/cars.do?query=manu&mid=6
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/cars.do?query=manu&mid=9
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=13
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=6
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=19
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/sell.do
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=17
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=2
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=25
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=24
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=21
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/insurance.do
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/about.do
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=18
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=29
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=7
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=23
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=38
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=5
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=27
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/cars.do?query=manu&mid=1
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=36
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=20
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=8
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=31
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=3
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=1
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=15
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/cars.do?query=manu&mid=3
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=14
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/cars.do?query=manu&mid=5
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/cars.do?query=manu&mid=8
# sending GET method to http://192.168.11.206:8080/Supercar-Trader/car.do?query=car&cid=32
